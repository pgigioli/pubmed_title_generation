# %%
import numpy as np
import os
import tensorflow as tf
import random
import re
from time import sleep
import math
import datetime
import time
import pickle
import layers
import functions
import decoder
import encoder
from dataset import PubMed_Dataset
import data_batcher
import models
import summarizer
import data_utils
from sys import stdout
from vocab import Vocab_Lookup

# %%
class Binary_Text_Classifier:
    def __init__(self, net, thresh=0.5, lr=0.001, mode='train'):
        self.thresh = thresh
        self.lr = lr
        
        self._inputs = net.inputs
        self._input_lens = net.input_lens
        self._dropout_keep_prob = net.dropout_keep_prob
        self._logits = net.logits
        self._max_len = net.max_len
        
        self._targets = tf.placeholder(tf.float32, [None, 1])
    
        self._sigmoid = tf.nn.sigmoid(self._logits)
        self._predictions = tf.to_float(self._sigmoid >= self.thresh)
        
        self._loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=self._targets, logits=self._logits))
        self._accuracy = tf.reduce_mean(tf.to_float(tf.equal(self._predictions, self._targets)))
                
        params = tf.trainable_variables()
        gradients, _ = tf.clip_by_global_norm(tf.gradients(self._loss, params), 1) 
        self._gradient_norm = tf.global_norm(gradients)
        opt_func = tf.train.AdamOptimizer(learning_rate=self.lr)
        self._optimizer = opt_func.apply_gradients(zip(gradients, params)) 
                
    def train_step(self, sess, inputs, input_lens, targets, dropout_keep_prob=1.0):
        run_vars = [self._loss, self._accuracy, self._gradient_norm, self._optimizer]
        loss, accuracy, grad_norm, _ = sess.run(run_vars, feed_dict={self._inputs : inputs,
                                                                     self._input_lens : input_lens,
                                                                     self._targets : targets,
                                                                     self._dropout_keep_prob : dropout_keep_prob})
        return loss, accuracy, grad_norm
        
    def val_step(self, sess, inputs, input_lens, targets):
        run_vars = [self._loss, self._accuracy]
        loss, accuracy = sess.run(run_vars, feed_dict={self._inputs : inputs,
                                                       self._input_lens : input_lens,
                                                       self._targets : targets,
                                                       self._dropout_keep_prob : 1.0})
        return loss, accuracy
        
    def deploy(self, sess, inputs, input_lens):
        run_vars = self._predictions
        predictions = sess.run(run_vars, feed_dict={self._inputs : inputs,
                                                    self._input_lens : input_lens,
                                                    self._dropout_keep_prob : 1.0})
        return predictions

# %%
meta_dir = os.path.join(os.getcwd(), 'PubMed')
log_dir = os.path.join(meta_dir, 'logs')
weights_dir = os.path.join(meta_dir, 'weights')
params_dir = os.path.join(meta_dir, 'params')
data_dir = os.path.join(meta_dir, 'data_cache')

# %%
#data = pickle.load(open("data.pickle", "rb"))
vocab_lookup = pickle.load(open(os.path.join(meta_dir, "vocab_lookup_30000.pickle"), "rb"))

# %%
train_files = []
val_files = []
test_files = []
for filename in os.listdir(data_dir):
    if 'train' in filename:
        train_files.append(os.path.join(data_dir, filename))
    elif 'val' in filename:
        val_files.append(os.path.join(data_dir, filename))
    elif 'test' in filename:
        test_files.append(os.path.join(data_dir, filename))

# %%
def data_partition_loader(partition_files):
    i = 0
    while True:
        partition_file = partition_files[i]
        i += 1
        yield pickle.load(open(partition_file, 'rb'))

# %%
train_partition_loader = data_partition_loader(train_files)
val_partition_loader = data_partition_loader(val_files)
test_partition_loader = data_partition_loader(test_files)

train_data = next(train_partition_loader)
val_data = next(val_partition_loader)
test_data = next(test_partition_loader)

# %%
batch_size = 128
train_batcher = data_batcher.Data_Batcher(train_data, batch_size)
val_batcher = data_batcher.Data_Batcher(val_data, batch_size)
test_batcher = data_batcher.Data_Batcher(test_data, batch_size)
deploy_batcher = data_batcher.Data_Batcher(val_data, 1)

# %%
d_pad_len = 150
s_pad_len = 20
embd_dim = 100
hidden_size = 256
n_layers = 4
vocab_size = vocab_lookup.num_words
dropout_keep_prob = 0.8
bidirectional = False

display_interval = 100
val_interval = 1000
deploy_interval = 1000
n_iters = 100000

lr = 0.001
DEVICE = 1
USE_CUDA = True
DEBUG_MODE = False

# w2v = pickle.load(open("w2v_CNN-Dailymail_100.pickle", "rb"))

# %%
pretrained_embeddings = None #functions.create_embeddings(vocab_lookup, w2v)

# %%
device_name = '/gpu:{}'.format(DEVICE) if USE_CUDA else '/cpu:{}'.format(DEVICE)

if USE_CUDA:
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
    os.environ["CUDA_VISIBLE_DEVICES"] = "{}".format(DEVICE)

tf.reset_default_graph()
with tf.device(device_name):
    net = models.RNN_Classifier(1, vocab_size, s_pad_len, embedding_dim=embd_dim, hidden_size=hidden_size, n_layers=n_layers, 
                                bidirectional=bidirectional, pretrained_embeddings=pretrained_embeddings, trainable_embeddings=True)
    model = Binary_Text_Classifier(net, thresh=0.5, lr=lr, mode='train')
    functions.count_params(tf.trainable_variables())
    for var in tf.trainable_variables(): print(var)
# Out:
# /home/ai2-leia/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# # Trainable Parameters: 4456385
# <tf.Variable 'embeddings_layer/embeddings:0' shape=(30000, 100) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_0/gru_cell/gates/kernel:0' shape=(356, 512) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_0/gru_cell/gates/bias:0' shape=(512,) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_0/gru_cell/candidate/kernel:0' shape=(356, 256) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_0/gru_cell/candidate/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_1/gru_cell/gates/kernel:0' shape=(512, 512) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_1/gru_cell/gates/bias:0' shape=(512,) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_1/gru_cell/candidate/kernel:0' shape=(512, 256) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_1/gru_cell/candidate/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_2/gru_cell/gates/kernel:0' shape=(512, 512) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_2/gru_cell/gates/bias:0' shape=(512,) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_2/gru_cell/candidate/kernel:0' shape=(512, 256) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_2/gru_cell/candidate/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_3/gru_cell/gates/kernel:0' shape=(512, 512) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_3/gru_cell/gates/bias:0' shape=(512,) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_3/gru_cell/candidate/kernel:0' shape=(512, 256) dtype=float32_ref>
# <tf.Variable 'encoder/multi_rnn_cell/cell_3/gru_cell/candidate/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'dense_output/output_W:0' shape=(256, 1) dtype=float32_ref>
# <tf.Variable 'dense_output/output_b:0' shape=(1,) dtype=float32_ref>

# %%
def replace_words(ids, real_len, rate):
    mask = [1 if random.random() < rate else 0 for _ in range(real_len-1)] + [0]*(len(ids)-real_len+1)
    cond = (np.array(mask) == 1)
    random_vals = [random.randint(4, vocab_size) for _ in range(len(ids))]
    return np.where(cond, random_vals, ids)

def repeat_words(ids, real_len, rate):
    mask = [1 if random.random() < rate else 0 for _ in range(real_len-1)] + [0]*(len(ids)-real_len+1)
    shift = [ids[0]] + ids[:-1]
    cond = (np.array(mask) == 1)
    return np.where(cond, shift, ids)

def single_repeated_word(ids, real_len, rate):
    mask = [1 if random.random() < rate else 0 for _ in range(real_len-1)] + [0]*(len(ids)-real_len+1)
    index = random.randint(0, real_len-1)
    inclusion = [ids[index] for _ in range(len(ids))]
    cond = (np.array(mask) == 1)
    return np.where(cond, inclusion, ids)

def shuffle_sequence(ids, real_len):
    return random.sample(ids[:real_len-1], real_len-1) + ids[real_len-1:]

def get_labeled_examples(examples, rate=0.15):
    inputs = []
    targets = []
    for example in examples:
        label = random.randint(0, 1)
        if label == 0:
            aug_type = random.randint(0, 3)
            if aug_type == 0:
                input_ids = shuffle_sequence(example.target_ids, example.target_len)
            elif aug_type == 1:
                input_ids = replace_words(example.target_ids, example.target_len, rate)
            elif aug_type == 2:
                input_ids = repeat_words(example.target_ids, example.target_len, rate)
            elif aug_type == 3:
                input_ids = single_repeated_word(example.target_ids, example.target_len, rate)
        else:
            input_ids = example.target_ids
        inputs.append(input_ids)
        targets.append([label])
    return inputs, targets

# %%
params = {key : value for key, value in net.__dict__.items() if not key.startswith('__') and not key.startswith('_')
          and not callable(key) and str(type(value)).find('tensorflow') == -1}
model_name = net.__class__.__name__

if not DEBUG_MODE:
    timestamp = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d_%H%M%S')
    log_file = os.path.join(log_dir, '{}_train_log_{}.txt'.format(model_name, timestamp))
    log_description = '0.8 dropout, classifier on titles, params: {}\n'.format(params)
    log = open(log_file, 'w')
    log.close()
    functions.write_to_log(log_description, log_file)
    
    params_filename = '{}_params_{}.pickle'.format(model_name, timestamp)
    with open(os.path.join(params_dir, params_filename), 'wb') as handle:
        pickle.dump(params, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
    checkpoint_dir = os.path.join(weights_dir, '{}_checkpoints_{}'.format(model_name, timestamp))
    os.mkdir(checkpoint_dir)

epoch = 0
with tf.Session(config=tf.ConfigProto(allow_soft_placement=True)) as sess:
    sess.run(tf.global_variables_initializer())
    
    if not DEBUG_MODE:
        saver = tf.train.Saver(max_to_keep=100)
     
    best_val_loss = 10e6
    for itr in range(1, n_iters+1):            
        examples, ep = train_batcher.next_batch()
        if ep == 1:
            try:
                train_data = next(train_partition_loader)
            except:
                epoch += 1
                train_partition_loader = data_partition_loader(train_files)
                train_data = next(train_partition_loader)
            train_batcher = data_batcher.Data_Batcher(train_data, batch_size)
            examples, ep = train_batcher.next_batch()
            
        inputs, targets = get_labeled_examples(examples)
        input_lens = [example.target_len for example in examples]

        train_loss, train_acc, grad_norm = model.train_step(sess, inputs, input_lens, targets, 
                                                            dropout_keep_prob=dropout_keep_prob)

        if itr % display_interval == 0 or itr == 1:     
            log_string = ('[%d, %5d] loss: %.3f, accuracy: %.3f, grad_norm: %.3f' 
                          % (epoch, itr, train_loss, train_acc, grad_norm))

            if not DEBUG_MODE:
                functions.write_to_log(log_string, log_file)
            print(log_string)
            
        if itr % val_interval == 0:
            val_loss, val_acc = 0.0, 0.0 
            for i in range(int(len(val_batcher.data)/val_batcher.batch_size)):
                examples, ep = val_batcher.next_batch()
                if ep == 1:
                    try:
                        val_data = next(val_partition_loader)
                    except:
                        val_partition_loader = data_partition_loader(val_files)
                        val_data = next(val_partition_loader)
                    val_batcher = data_batcher.Data_Batcher(val_data, batch_size)
                    examples, ep = val_batcher.next_batch()
                inputs, targets = get_labeled_examples(examples)
                input_lens = [example.target_len for example in examples]

                val_batch_loss, val_batch_acc = model.val_step(sess, inputs, input_lens, targets)
                val_loss += ((val_batch_loss - val_loss)/(i+1))
                val_acc += ((val_batch_acc - val_acc)/(i+1))
                #val_loss.append(val_batch_loss)
                #val_acc.append(val_batch_acc)
                if (i+1)*val_batcher.batch_size >= 10000:
                    break
            #val_loss = np.mean(val_loss)
            #val_acc = np.mean(val_acc)
            log_string = ('Validation - loss: %.3f, accuracy: %.3f' % (val_loss, val_acc))

            if not DEBUG_MODE:
                functions.write_to_log(log_string, log_file)
            print(log_string)
            
            if not DEBUG_MODE:
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    weights_prefix = '{}_weights_epoch_{}_itr_{}'.format(model_name, epoch, itr)
                    log_msg = "Weights saved in file: {}\n".format(os.path.join(checkpoint_dir, weights_prefix))
                    print(log_msg)
                    saver.save(sess, os.path.join(checkpoint_dir, weights_prefix))
                    functions.write_to_log(log_msg, log_file)
            
        if itr % deploy_interval == 0:
            examples, _ = deploy_batcher.next_batch()
            example = examples[0]
            shuffled_input = shuffle_sequence(example.target_ids, example.target_len)
            replaced_input = replace_words(example.target_ids, example.target_len, 0.15)
            repeated_input = repeat_words(example.target_ids, example.target_len, 0.15)
            single_repeated_input = single_repeated_word(example.target_ids, example.target_len, 0.15)
            inputs = [example.target_ids, shuffled_input, replaced_input, repeated_input, single_repeated_input]
            input_lens = [example.target_len]*5
            
            replaced_sentence = ' '.join([vocab_lookup.convert_id2word(idx) for idx in replaced_input])
            shuffled_sentence = ' '.join([vocab_lookup.convert_id2word(idx) for idx in shuffled_input])
            repeated_sentence = ' '.join([vocab_lookup.convert_id2word(idx) for idx in repeated_input])
            single_repeated_sentence = ' '.join([vocab_lookup.convert_id2word(idx) for idx in single_repeated_input])
            predictions = model.deploy(sess, inputs, input_lens)
            
            log_string = ('INPUT:\n{}\nSHUFFLED:\n{}\nREPLACED:\n{}\nREPEATED:\n{}\nSINGLE REPEAT:\n{}\nMODEL: {}'
                          .format(example.target_text, shuffled_sentence, replaced_sentence, repeated_sentence, 
                                  single_repeated_sentence, predictions))
            if not DEBUG_MODE:
                functions.write_to_log(log_string, log_file)
            print(log_string)
# Out:
# [0,     1] loss: 0.688, accuracy: 0.500, grad_norm: 0.696
# [0,   100] loss: 0.695, accuracy: 0.547, grad_norm: 0.711
# [0,   200] loss: 0.664, accuracy: 0.594, grad_norm: 0.863
# [0,   300] loss: 0.674, accuracy: 0.570, grad_norm: 0.892
# [0,   400] loss: 0.581, accuracy: 0.680, grad_norm: 0.737
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_3000
#
# INPUT:
# Mangiferin attenuates MPTP induced dopaminergic neurodegeneration and improves motor impairment, redox balance and Bcl-2/Bax expression in experimental Parkinson's disease mice.
# SHUFFLED:
# expression 2 neurodegeneration improves in and balance induced impairment bcl redox experimental bax UNK mptp attenuates motor and dopaminergic EOS
# REPLACED:
# UNK attenuates mptp breadth dopaminergic neurodegeneration and improves motor impairment redox balance and done. 2 bax expression in experimental EOS
# REPEATED:
# UNK attenuates mptp induced dopaminergic neurodegeneration and improves motor motor redox redox and bcl 2 bax expression in experimental EOS
# SINGLE REPEAT:
# UNK attenuates mptp induced dopaminergic neurodegeneration and improves motor impairment redox balance and bcl 2 bax expression in experimental EOS
# MODEL: [[ 1.]
#  [ 0.]
#  [ 1.]
#  [ 1.]
#  [ 1.]]
# [0,  3100] loss: 0.546, accuracy: 0.750, grad_norm: 0.567
# [0,  3200] loss: 0.495, accuracy: 0.758, grad_norm: 0.360
# [0,  3300] loss: 0.518, accuracy: 0.773, grad_norm: 0.769
# [0,  3400] loss: 0.405, accuracy: 0.805, grad_norm: 0.345
# [0,  3500] loss: 0.493, accuracy: 0.734, grad_norm: 0.627
# [0,  3600] loss: 0.393, accuracy: 0.812, grad_norm: 0.414
# [0,  3700] loss: 0.485, accuracy: 0.734, grad_norm: 0.499
# [0,  3800] loss: 0.407, accuracy: 0.789, grad_norm: 1.000
# [0,  3900] loss: 0.470, accuracy: 0.805, grad_norm: 0.430
# [0,  4000] loss: 0.405, accuracy: 0.789, grad_norm: 0.421
# Validation - loss: 0.432, accuracy: 0.793
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_4000
#
# INPUT:
# Determination of the herbicide desmetryne in organised media by adsorptive stripping voltammetry.
# SHUFFLED:
# voltammetry determination stripping organised adsorptive herbicide media of in the UNK by . EOS PAD PAD PAD PAD PAD PAD
# REPLACED:
# determination ebpbeta the herbicide exists in organised media by adsorptive stripping voltammetry eggs EOS PAD PAD PAD PAD PAD PAD
# REPEATED:
# determination of the herbicide herbicide in organised media media by stripping voltammetry . EOS PAD PAD PAD PAD PAD PAD
# SINGLE REPEAT:
# determination of the herbicide . in organised . . adsorptive stripping voltammetry . EOS PAD PAD PAD PAD PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 1.]
#  [ 0.]]
# [0,  4100] loss: 0.423, accuracy: 0.797, grad_norm: 0.365
# [0,  4200] loss: 0.401, accuracy: 0.812, grad_norm: 0.557
# [0,  4300] loss: 0.410, accuracy: 0.852, grad_norm: 0.308
# [0,  4400] loss: 0.481, accuracy: 0.742, grad_norm: 0.310
# [0,  4500] loss: 0.427, accuracy: 0.797, grad_norm: 0.542
# [0,  4600] loss: 0.346, accuracy: 0.875, grad_norm: 0.321
# [0,  4700] loss: 0.451, accuracy: 0.812, grad_norm: 0.438
# [0,  4800] loss: 0.349, accuracy: 0.852, grad_norm: 0.309
# [0,  4900] loss: 0.354, accuracy: 0.852, grad_norm: 0.281
# [0,  5000] loss: 0.404, accuracy: 0.836, grad_norm: 0.303
# Validation - loss: 0.410, accuracy: 0.809
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_5000
#
# INPUT:
# Reliability and validity of the Arabic version of "dermatitis family impact" questionnaire in children with atopic dermatitis.
# SHUFFLED:
# the with dermatitis of . in family children dermatitis and reliability validity of atopic version arabic impact questionnaire EOS PAD
# REPLACED:
# aldehyde and validity of the arabic washout of dermatitis family impact questionnaire in children with atopic dermatitis . EOS PAD
# REPEATED:
# reliability and validity of the the version of dermatitis family impact questionnaire in children with with dermatitis . EOS PAD
# SINGLE REPEAT:
# reliability and validity of the arabic version of dermatitis family impact questionnaire in children questionnaire atopic dermatitis . EOS PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 1.]
#  [ 0.]
#  [ 1.]]
# [0,  5100] loss: 0.430, accuracy: 0.773, grad_norm: 0.387
# [0,  5200] loss: 0.401, accuracy: 0.797, grad_norm: 0.275
# [0,  5300] loss: 0.374, accuracy: 0.836, grad_norm: 0.296
# [0,  5400] loss: 0.354, accuracy: 0.883, grad_norm: 0.366
# [0,  5500] loss: 0.451, accuracy: 0.773, grad_norm: 0.453
# [0,  5600] loss: 0.418, accuracy: 0.852, grad_norm: 0.415
# [0,  5700] loss: 0.390, accuracy: 0.820, grad_norm: 0.455
# [0,  5800] loss: 0.380, accuracy: 0.828, grad_norm: 0.320
# [0,  5900] loss: 0.288, accuracy: 0.875, grad_norm: 0.292
# [0,  6000] loss: 0.328, accuracy: 0.867, grad_norm: 0.443
# Validation - loss: 0.397, accuracy: 0.821
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_6000
#
# INPUT:
# Phosphorylation of mammalian cytochrome c and cytochrome c oxidase in the regulation of cell destiny: respiration, apoptosis, and human disease.
# SHUFFLED:
# regulation cytochrome phosphorylation in mammalian the oxidase respiration apoptosis of cell cytochrome c c of and and human UNK EOS
# REPLACED:
# phosphorylation of mammalian cytochrome judgements and cytochrome c rubidium in the regulation of footprinting UNK macroscopic apoptosis and human EOS
# REPEATED:
# phosphorylation of mammalian cytochrome c and and c oxidase in the regulation of cell UNK respiration apoptosis and human EOS
# SINGLE REPEAT:
# phosphorylation of mammalian cytochrome c and cytochrome c oxidase cell the regulation of cell cell respiration apoptosis and human EOS
# MODEL: [[ 1.]
#  [ 0.]
#  [ 1.]
#  [ 0.]
#  [ 1.]]
# [0,  6100] loss: 0.465, accuracy: 0.766, grad_norm: 0.338
# [0,  6200] loss: 0.426, accuracy: 0.766, grad_norm: 0.372
# [0,  6300] loss: 0.461, accuracy: 0.797, grad_norm: 0.352
# [0,  6400] loss: 0.463, accuracy: 0.758, grad_norm: 0.385
# [0,  6500] loss: 0.419, accuracy: 0.805, grad_norm: 0.450
# [0,  6600] loss: 0.381, accuracy: 0.828, grad_norm: 0.340
# [0,  6700] loss: 0.337, accuracy: 0.852, grad_norm: 0.370
# [0,  6800] loss: 0.393, accuracy: 0.797, grad_norm: 0.330
# [0,  6900] loss: 0.496, accuracy: 0.781, grad_norm: 0.610
# [0,  7000] loss: 0.364, accuracy: 0.844, grad_norm: 0.246
# Validation - loss: 0.390, accuracy: 0.823
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_7000
#
# INPUT:
# Disease with abnormal intracranial vascular network complicated with intracerebral haematoma.
# SHUFFLED:
# intracerebral intracranial with network with disease complicated vascular abnormal . haematoma EOS PAD PAD PAD PAD PAD PAD PAD PAD
# REPLACED:
# hypomethylation with abnormal intracranial vascular vasodilator complicated with intracerebral haematoma . EOS PAD PAD PAD PAD PAD PAD PAD PAD
# REPEATED:
# disease with abnormal abnormal vascular vascular complicated with intracerebral haematoma . EOS PAD PAD PAD PAD PAD PAD PAD PAD
# SINGLE REPEAT:
# disease with abnormal intracranial vascular with complicated with intracerebral haematoma with EOS PAD PAD PAD PAD PAD PAD PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 1.]
#  [ 1.]
#  [ 0.]]
# [0,  7100] loss: 0.404, accuracy: 0.820, grad_norm: 0.254
# [0,  7200] loss: 0.360, accuracy: 0.852, grad_norm: 0.260
# [0,  7300] loss: 0.385, accuracy: 0.812, grad_norm: 0.293
# [0,  7400] loss: 0.376, accuracy: 0.812, grad_norm: 0.262
# [0,  7500] loss: 0.330, accuracy: 0.844, grad_norm: 0.327
# [0,  7600] loss: 0.329, accuracy: 0.875, grad_norm: 0.227
# [0,  7700] loss: 0.433, accuracy: 0.797, grad_norm: 0.305
# [0,  7800] loss: 0.426, accuracy: 0.820, grad_norm: 0.387
# [0,  7900] loss: 0.366, accuracy: 0.844, grad_norm: 0.544
# [0,  8000] loss: 0.327, accuracy: 0.867, grad_norm: 0.232
# Validation - loss: 0.383, accuracy: 0.826
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_8000
#
# INPUT:
# Effect of reperfusion on the uptake of [3H] uridine in the gerbil brain after prolonged ischaemia.
# SHUFFLED:
# uptake of of 3h brain in effect ischaemia after uridine . prolonged the gerbil on reperfusion the EOS PAD PAD
# REPLACED:
# effect of reperfusion on the uptake of individually uridine in the gerbil brain after prolonged ischaemia . EOS PAD PAD
# REPEATED:
# effect of reperfusion reperfusion the uptake of 3h uridine in the gerbil brain after after ischaemia . EOS PAD PAD
# SINGLE REPEAT:
# effect of reperfusion on the uptake of 3h uridine of the gerbil brain after prolonged ischaemia . EOS PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 1.]
#  [ 0.]
#  [ 1.]]
# [0,  8100] loss: 0.469, accuracy: 0.758, grad_norm: 0.316
# [0,  8200] loss: 0.370, accuracy: 0.836, grad_norm: 0.256
# [0,  8300] loss: 0.425, accuracy: 0.797, grad_norm: 0.256
# [0,  8400] loss: 0.366, accuracy: 0.805, grad_norm: 0.252
# [0,  8500] loss: 0.333, accuracy: 0.859, grad_norm: 0.320
# [0,  8600] loss: 0.298, accuracy: 0.898, grad_norm: 0.274
# [0,  8700] loss: 0.352, accuracy: 0.844, grad_norm: 0.261
# [0,  8800] loss: 0.450, accuracy: 0.781, grad_norm: 0.283
# [0,  8900] loss: 0.305, accuracy: 0.883, grad_norm: 0.237
# [0,  9000] loss: 0.299, accuracy: 0.875, grad_norm: 0.213
# Validation - loss: 0.381, accuracy: 0.826
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_9000
#
# INPUT:
# EBNA-1, the major nuclear antigen of Epstein-Barr virus, resembles 'RGG' RNA binding proteins.
# SHUFFLED:
# virus 1 resembles binding the rna barr of antigen proteins ebna nuclear UNK . epstein major EOS PAD PAD PAD
# REPLACED:
# ebna sons the major nuclear antigen of epstein barr virus resembles UNK rna pokeweed proteins . EOS PAD PAD PAD
# REPEATED:
# ebna 1 the major nuclear antigen of epstein barr virus resembles UNK rna binding proteins proteins EOS PAD PAD PAD
# SINGLE REPEAT:
# ebna 1 the major nuclear antigen of epstein barr virus resembles UNK rna binding proteins . EOS PAD PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 1.]]
# [0,  9100] loss: 0.361, accuracy: 0.820, grad_norm: 0.305
# [0,  9200] loss: 0.357, accuracy: 0.836, grad_norm: 0.273
# [0,  9300] loss: 0.301, accuracy: 0.891, grad_norm: 0.226
# [0,  9400] loss: 0.439, accuracy: 0.797, grad_norm: 0.272
# [0,  9500] loss: 0.409, accuracy: 0.805, grad_norm: 0.337
# [0,  9600] loss: 0.364, accuracy: 0.852, grad_norm: 0.212
# [0,  9700] loss: 0.310, accuracy: 0.875, grad_norm: 0.217
# [0,  9800] loss: 0.332, accuracy: 0.852, grad_norm: 0.189
# [0,  9900] loss: 0.309, accuracy: 0.852, grad_norm: 0.213
# [0, 10000] loss: 0.284, accuracy: 0.906, grad_norm: 0.189
# Validation - loss: 0.369, accuracy: 0.838
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_10000
#
# INPUT:
# Growth changes of the mandibular body with eruption of mandibular third molars: analysis of anatomical morphometry and quantitative bone mineral content by using radiography.
# SHUFFLED:
# anatomical of and third quantitative morphometry mandibular changes mandibular of molars eruption of the bone with body analysis growth EOS
# REPLACED:
# growth changes aureus the mandibular body with eruption of mandibular third molars analysis of anatomical morphometry and quantitative bone EOS
# REPEATED:
# growth changes of the mandibular body with eruption of mandibular third third analysis of anatomical morphometry and quantitative bone EOS
# SINGLE REPEAT:
# growth changes of and mandibular and with eruption of and and molars analysis and anatomical morphometry and quantitative bone EOS
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 1.]
#  [ 0.]]
# [0, 10100] loss: 0.372, accuracy: 0.828, grad_norm: 0.397
# [0, 10200] loss: 0.385, accuracy: 0.836, grad_norm: 0.242
# [0, 10300] loss: 0.356, accuracy: 0.820, grad_norm: 0.267
# [0, 10400] loss: 0.443, accuracy: 0.789, grad_norm: 0.480
# [0, 10500] loss: 0.352, accuracy: 0.852, grad_norm: 0.253
# [0, 10600] loss: 0.429, accuracy: 0.797, grad_norm: 0.236
# [0, 10700] loss: 0.373, accuracy: 0.836, grad_norm: 0.212
# [0, 10800] loss: 0.324, accuracy: 0.859, grad_norm: 0.193
# [0, 10900] loss: 0.376, accuracy: 0.852, grad_norm: 0.205
# [0, 11000] loss: 0.467, accuracy: 0.789, grad_norm: 0.349
# Validation - loss: 0.354, accuracy: 0.843
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_11000
#
# INPUT:
# Thirty years and counting: finding meaning in the N400 component of the event-related brain potential (ERP).
# SHUFFLED:
# in finding component event meaning erp and . related the the years brain thirty n400 counting of potential EOS PAD
# REPLACED:
# thirty carcinogenic sores counting finding meaning in the n400 component of conceptus event related brain potential erp . EOS PAD
# REPEATED:
# thirty years and counting counting meaning in the n400 n400 of the event related brain potential erp . EOS PAD
# SINGLE REPEAT:
# thirty years and years finding meaning years the years years of the event related brain potential erp years EOS PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 1.]
#  [ 0.]
#  [ 0.
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_14000
#
# INPUT:
# Fe-Ce-ZSM-5 a new catalyst of outstanding properties in the selective catalytic reduction of NO with NH(3).
# SHUFFLED:
# properties UNK catalytic new fe nh with 5 no ce catalyst of reduction of a selective in outstanding the EOS
# REPLACED:
# fe ce legs 5 a new snc of outstanding properties postures the selective catalytic con ht1a no with silence EOS
# REPEATED:
# fe ce UNK 5 a new catalyst of of properties in in selective catalytic reduction of no no nh EOS
# SINGLE REPEAT:
# fe ce UNK 5 a new catalyst of outstanding properties in the selective catalytic reduction of of with nh EOS
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]
# [0, 14100] loss: 0.368, accuracy: 0.828, grad_norm: 0.230
# [0, 14200] loss: 0.347, accuracy: 0.859, grad_norm: 0.269
# [0, 14300] loss: 0.257, accuracy: 0.914, grad_norm: 0.199
# [0, 14400] loss: 0.413, accuracy: 0.844, grad_norm: 0.298
# [0, 14500] loss: 0.363, accuracy: 0.859, grad_norm: 0.238
# [0, 14600] loss: 0.321, accuracy: 0.828, grad_norm: 0.258
# [0, 14700] loss: 0.330, accuracy: 0.859, grad_norm: 0.313
# [0, 14800] loss: 0.406, accuracy: 0.781, grad_norm: 0.307
# [0, 14900] loss: 0.366, accuracy: 0.844, grad_norm: 0.266
# [0, 15000] loss: 0.309, accuracy: 0.867, grad_norm: 0.261
# Validation - loss: 0.328, accuracy: 0.863
# INPUT:
# Functional and structural relevance of conserved positively charged lysine residues in organic anion transporting polypeptide 1B3.
# SHUFFLED:
# relevance in organic residues anion transporting . lysine of charged functional conserved UNK positively and polypeptide structural EOS PAD PAD
# REPLACED:
# functional and structural relevance of conserved positively charged lysine dibenzofurans prairie organic anion transporting charcoal UNK . EOS PAD PAD
# REPEATED:
# functional and structural relevance of conserved positively positively lysine residues in organic anion transporting transporting UNK . EOS PAD PAD
# SINGLE REPEAT:
# functional and structural relevance of transporting transporting transporting lysine residues in organic transporting transporting polypeptide UNK . EOS PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]
# [0, 15100] loss: 0.357, accuracy: 0.836, grad_norm: 0.232
# [0, 15200] loss: 0.294, accuracy: 0.883, grad_norm: 0.185
# [0, 15300] loss: 0.357, accuracy: 0.844, grad_norm: 0.230
# [0, 15400] loss: 0.285, accuracy: 0.875, grad_norm: 0.206
# [0, 15500] loss: 0.292, accuracy: 0.898, grad_norm: 0.216
# [0, 15600] loss: 0.256, accuracy: 0.891, grad_norm: 0.266
# [0, 15700] loss: 0.418, accuracy: 0.820, grad_norm: 0.332
# [0, 15800] loss: 0.257, accuracy: 0.891, grad_norm: 0.173
# [0, 15900] loss: 0.369, accuracy: 0.820, grad_norm: 0.287
# [0, 16000] loss: 0.277, accuracy: 0.914, grad_norm: 0.189
# Validation - loss: 0.329, accuracy: 0.864
# INPUT:
# Primary and secondary structure of a 360-nucleotide isolate of potato spindle tuber viroid.
# SHUFFLED:
# structure potato primary a and of isolate nucleotide spindle tuber secondary UNK 360 . of EOS PAD PAD PAD PAD
# REPLACED:
# primary and secondary structure of ceftriaxone menstrual nucleotide isolate of potato spindle tuber UNK . EOS PAD PAD PAD PAD
# REPEATED:
# primary and secondary structure of a 360 nucleotide isolate isolate potato spindle tuber UNK . EOS PAD PAD PAD PAD
# SINGLE REPEAT:
# primary UNK secondary structure of a 360 UNK UNK of potato UNK UNK UNK . EOS PAD PAD PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_23000
#
# INPUT:
# Differentiating fall-prone and healthy adults using local dynamic stability.
# SHUFFLED:
# fall stability differentiating local prone using healthy dynamic adults and . EOS PAD PAD PAD PAD PAD PAD PAD PAD
# REPLACED:
# differentiating fall prone and healthy director ect local las stability southwest EOS PAD PAD PAD PAD PAD PAD PAD PAD
# REPEATED:
# differentiating fall prone and healthy adults using local dynamic stability stability EOS PAD PAD PAD PAD PAD PAD PAD PAD
# SINGLE REPEAT:
# differentiating fall prone and healthy adults dynamic local dynamic stability . EOS PAD PAD PAD PAD PAD PAD PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 1.]]
# [0, 23100] loss: 0.319, accuracy: 0.883, grad_norm: 0.202
# [0, 23200] loss: 0.349, accuracy: 0.844, grad_norm: 0.244
# [0, 23300] loss: 0.258, accuracy: 0.898, grad_norm: 0.270
# [0, 23400] loss: 0.262, accuracy: 0.898, grad_norm: 0.172
# [0, 23500] loss: 0.384, accuracy: 0.844, grad_norm: 0.188
# [0, 23600] loss: 0.391, accuracy: 0.820, grad_norm: 0.251
# [0, 23700] loss: 0.436, accuracy: 0.805, grad_norm: 0.304
# [0, 23800] loss: 0.336, accuracy: 0.852, grad_norm: 0.247
# [0, 23900] loss: 0.261, accuracy: 0.891, grad_norm: 0.179
# [0, 24000] loss: 0.272, accuracy: 0.906, grad_norm: 0.190
# Validation - loss: 0.287, accuracy: 0.884
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_24000
#
# INPUT:
# Validation of a modified version of the Brief Pain Inventory for painful diabetic peripheral neuropathy.
# SHUFFLED:
# brief version . validation the of modified for painful neuropathy of a peripheral pain inventory diabetic EOS PAD PAD PAD
# REPLACED:
# validation of a modified version of azido brief pain inventory for painful diabetic peripheral neuropathy . EOS PAD PAD PAD
# REPEATED:
# validation validation a modified version version the brief brief inventory for painful diabetic peripheral peripheral . EOS PAD PAD PAD
# SINGLE REPEAT:
# for of a modified version of the brief pain inventory for painful for peripheral neuropathy . EOS PAD PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 1.]
#  [ 0.]
#  [ 0.]]
# [0, 24100] loss: 0.196, accuracy: 0.930, grad_norm: 0.175
# [0, 24200] loss: 0.252, accuracy: 0.898, grad_norm: 0.197
# [0, 24300] loss: 0.313, accuracy: 0.867, grad_norm: 0.173
# [0, 24400] loss: 0.240, accuracy: 0.906, grad_norm: 0.217
# [0, 24500] loss: 0.265, accuracy: 0.906, grad_norm: 0.184
# [0, 24600] loss: 0.259, accuracy: 0.922, grad_norm: 0.266
# [0, 24700] loss: 0.270, accuracy: 0.898, grad_norm: 0.157
# [0, 24800] loss: 0.386, accuracy: 0.805, grad_norm: 0.256
# [0, 24900] loss: 0.408, accuracy: 0.812, grad_norm: 0.216
# [0, 25000] loss: 0.293, accuracy: 0.891, grad_norm: 0.196
# Validation - loss: 0.306, accuracy: 0.875
# INPUT:
# Activin A skews macrophage polarization by promoting a proinflammatory phenotype and inhibiting the acquisition of anti-inflammatory macrophage markers.
# SHUFFLED:
# macrophage macrophage and the inhibiting inflammatory UNK polarization phenotype anti of activin a acquisition markers proinflammatory a promoting by EOS
# REPLACED:
# all. a 2e macrophage polarization by promoting excess proinflammatory phenotype and inhibiting the acquisition of anti inflammatory macrophage neu EOS
# REPEATED:
# activin a a macrophage polarization by promoting promoting proinflammatory phenotype and inhibiting the acquisition of anti inflammatory macrophage markers EOS
# SINGLE REPEAT:
# activin a UNK polarization polarization by promoting a polarization phenotype and inhibiting polarization acquisition of polarization inflammatory macrophage markers EOS
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]
# [0, 25100] loss: 0.271, accuracy: 0.914, grad_norm: 0.351
# [0, 25200] loss: 0.305, accuracy: 0.898, grad_norm: 0.168
# [0, 25300] loss: 0.349, accuracy: 0.844, grad_norm: 0.256
# [0, 25400] loss: 0.340, accuracy: 0.867, grad_norm: 0.285
# [0, 25500] loss: 0.303, accuracy: 0.898, grad_norm: 0.263
# [0, 25600] loss: 0.288, accuracy: 0.852, grad_norm: 0.231
# [0, 25700] loss: 0.309, accuracy: 0.891, grad_norm: 0.222
# [0, 25800] loss: 0.281, accuracy: 0.898, grad_norm: 0.195
# [0, 25900] loss: 0.287, accuracy: 0.883, grad_norm: 0.164
# [0, 26000] loss: 0.288, accuracy: 0.867, grad_norm: 0.170
# Validation - loss: 0.304, accuracy: 0.876
# INPUT:
# The herpes simplex virus type 1 origin-binding protein interacts specifically with the viral UL8 protein.
# SHUFFLED:
# protein type viral UNK protein the herpes simplex origin with . 1 virus the binding specifically interacts EOS PAD PAD
# REPLACED:
# radiologists herpes simplex virus type 1 origin binding protein interacts specifically objectives the plasmids UNK protein dbcamp EOS PAD PAD
# REPEATED:
# the herpes simplex virus virus 1 origin origin protein interacts specifically with the viral UNK protein . EOS PAD PAD
# SINGLE REPEAT:
# the herpes simplex virus type 1 origin binding protein interacts binding with binding viral UNK protein . EOS PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]
# [0, 26100] loss: 0.307, accuracy: 0.852, grad_norm: 0.230
# [0, 26200] loss: 0.342, accuracy: 0.859, grad_norm: 0.266
# [0, 26300] loss: 0.259, accuracy: 0.883, grad_norm: 0.166
# [0, 26400] loss: 0.294, accuracy: 0.875, grad_norm: 0.154
# [0, 26500] loss: 0.347, accuracy: 0.859, grad_norm: 0.186
# [0, 26600] loss: 0.256, accuracy: 0.891, grad_norm: 0.158
# [0, 26700] loss: 0.264, accuracy: 0.898, grad_norm: 0.238
# [0, 26800] loss: 0.319, accuracy: 0.859, grad_norm: 0.182
# [0, 26900] loss: 0.329, accuracy: 0.859, grad_norm: 0.184
# [0, 27000] loss: 0.282, accuracy: 0.891, grad_norm: 0.158
# Validation - loss: 0.291, accuracy: 0.883
# INPUT:
# Dimer structure and conformational variability in the N-terminal region of an archaeal small heat shock protein, StHsp14.0.
# SHUFFLED:
# terminal region heat in protein variability an conformational shock UNK and structure n archaeal dimer . the small of EOS
# REPLACED:
# fungicide structure and extended variability in the n terminal region phenotype. an archaeal mutational heat shock impart diminished . EOS
# REPEATED:
# dimer structure structure conformational conformational in the n terminal region of an an small small heat protein UNK . EOS
# SINGLE REPEAT:
# dimer structure and terminal variability in the n terminal region terminal an archaeal small heat shock protein UNK . EOS
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]
# [0, 36800] loss: 0.292, accuracy: 0.898, grad_norm: 0.127
# [0, 36900] loss: 0.255, accuracy: 0.891, grad_norm: 0.208
# [0, 37000] loss: 0.197, accuracy: 0.938, grad_norm: 0.123
# Validation - loss: 0.293, accuracy: 0.884
# INPUT:
# Choice reaction time after levodopa challenge in parkinsonian patients.
# SHUFFLED:
# choice time parkinsonian levodopa after challenge reaction in . patients EOS PAD PAD PAD PAD PAD PAD PAD PAD PAD
# REPLACED:
# choice reaction time after levodopa challenge in keratitis patients . EOS PAD PAD PAD PAD PAD PAD PAD PAD PAD
# REPEATED:
# choice reaction time after after challenge in parkinsonian patients . EOS PAD PAD PAD PAD PAD PAD PAD PAD PAD
# SINGLE REPEAT:
# choice reaction time after levodopa challenge in reaction patients . EOS PAD PAD PAD PAD PAD PAD PAD PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 1.]
#  [ 0.]
#  [ 0.]]
# [0, 37100] loss: 0.267, accuracy: 0.891, grad_norm: 0.182
# [0, 37200] loss: 0.282, accuracy: 0.859, grad_norm: 0.199
# [0, 37300] loss: 0.304, accuracy: 0.875, grad_norm: 0.197
# [0, 37400] loss: 0.287, accuracy: 0.891, grad_norm: 0.181
# [0, 37500] loss: 0.335, accuracy: 0.867, grad_norm: 0.226
# [0, 37600] loss: 0.254, accuracy: 0.891, grad_norm: 0.142
# [0, 37700] loss: 0.250, accuracy: 0.891, grad_norm: 0.177
# [0, 37800] loss: 0.345, accuracy: 0.852, grad_norm: 0.218
# [0, 37900] loss: 0.304, accuracy: 0.898, grad_norm: 0.172
# [0, 38000] loss: 0.338, accuracy: 0.836, grad_norm: 0.221
# Validation - loss: 0.284, accuracy: 0.887
# Weights saved in file: /home/ai2-leia/Documents/code/paul/deep_NLP/Summarization/PubMed/weights/RNN_Classifier_checkpoints_20171117_114517/RNN_Classifier_weights_epoch_0_itr_38000
#
# INPUT:
# The curriculum of practice: a conceptual framework for speech-language therapy and audiology practice with a black African first language clientele.
# SHUFFLED:
# conceptual practice of curriculum framework with the black a therapy first a practice and speech for UNK african language EOS
# REPLACED:
# the curriculum of practice a conceptual framework for speech language therapy and UNK practice with a black african first EOS
# REPEATED:
# the curriculum of practice a conceptual framework for speech language therapy and UNK practice with with black black first EOS
# SINGLE REPEAT:
# the curriculum and practice a conceptual framework for speech language therapy and UNK practice and a black african first EOS
# MODEL: [[ 1.]
#  [ 1.]
#  [ 1.]
#  [ 0.]
#  [ 1.]]
# [0, 38100] loss: 0.237, accuracy: 0.922, grad_norm: 0.214
# [0, 38200] loss: 0.271, accuracy: 0.898, grad_norm: 0.230
# [0, 38300] loss: 0.255, accuracy: 0.906, grad_norm: 0.214
# [0, 38400] loss: 0.273, accuracy: 0.898, grad_norm: 0.181
# [0, 38500] loss: 0.266, accuracy: 0.906, grad_norm: 0.193
# [0, 38600] loss: 0.240, accuracy: 0.906, grad_norm: 0.151
# [0, 38700] loss: 0.281, accuracy: 0.883, grad_norm: 0.209
# [0, 38800] loss: 0.340, accuracy: 0.852, grad_norm: 0.173
# [0, 38900] loss: 0.249, accuracy: 0.914, grad_norm: 0.154
# [0, 39000] loss: 0.203, accuracy: 0.914, grad_norm: 0.201
# Validation - loss: 0.289, accuracy: 0.885
# INPUT:
# Boosting Wnt activity during colorectal cancer progression through selective hypermethylation of Wnt signaling antagonists.
# SHUFFLED:
# selective . colorectal cancer during progression wnt antagonists hypermethylation activity signaling of boosting through wnt EOS PAD PAD PAD PAD
# REPLACED:
# boosting wnt 294 during colorectal cancer progression through selective hypermethylation of wnt signaling antagonists . EOS PAD PAD PAD PAD
# REPEATED:
# boosting wnt activity during colorectal cancer progression progression selective hypermethylation hypermethylation wnt signaling signaling antagonists EOS PAD PAD PAD PAD
# SINGLE REPEAT:
# of wnt of during colorectal cancer progression through selective hypermethylation of of signaling antagonists of EOS PAD PAD PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 1.]
#  [ 0.]
#  [ 0.]]
# [0, 39100] loss: 0.276, accuracy: 0.891, grad_norm: 0.264
# [0, 39200] loss: 0.239, accuracy: 0.883, grad_norm: 0.372
# [0, 39300] loss: 0.288, accuracy: 0.891, grad_norm: 0.155
# [0, 39400] loss: 0.229, accuracy: 0.914, grad_norm: 0.203
# [0, 39500] loss: 0.293, accuracy: 0.891, grad_norm: 0.191
# [0, 39600] loss: 0.317, accuracy: 0.891, grad_norm: 0.161
# [0, 39700] loss: 0.240, accuracy: 0.906, grad_norm: 0.288
# [0, 39800] loss: 0.235, accuracy: 0.891, grad_norm: 0.198
# [0, 39900] loss: 0.270, accuracy: 0.898, grad_norm: 0.219
# [0, 40000] loss: 0.264, accuracy: 0.906, grad_norm: 0.177
# Validation - loss: 0.290, accuracy: 0.885
# INPUT:
# The sociology of Qi Gong: a qualitative study.
# SHUFFLED:
# . the qi UNK UNK of study qualitative a EOS PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# REPLACED:
# msd UNK wheel qi UNK a vif study . EOS PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# REPEATED:
# the UNK of qi qi a qualitative qualitative . EOS PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# SINGLE REPEAT:
# the UNK EOS qi EOS EOS qualitative study EOS EOS PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]
# [0, 40100] loss: 0.279, accuracy: 0.883, grad_norm: 0.213
# [0, 40200] loss: 0.262, accuracy: 0.891, grad_norm: 0.162
# [0, 40300] loss: 0.242, accuracy: 0.914, grad_norm: 0.226
# [0, 40400] loss: 0.193, accuracy: 0.945, grad_norm: 0.233
# [0, 40500] loss: 0.298, accuracy: 0.875, grad_norm: 0.160
# [0, 40600] loss: 0.244, accuracy: 0.906, grad_norm: 0.262
# [0, 40700] loss: 0.266, accuracy: 0.914, grad_norm: 0.136
# [0, 40800] loss: 0.279, accuracy: 0.867, grad_norm: 0.199
# [0, 40900] loss: 0.282, accuracy: 0.883, grad_norm: 0.173
# [0, 41000] loss: 0.349, accuracy: 0.828, grad_norm: 0.200
# Validation - loss: 0.286, accuracy: 0.884
# INPUT:
# Association analyses of insulin signaling pathway gene polymorphisms with healthy aging and longevity in Americans of Japanese ancestry.
# SHUFFLED:
# signaling pathway americans gene of polymorphisms with in . analyses and aging association insulin japanese healthy ancestry longevity of EOS
# REPLACED:
# association dmh of insulin signaling pathway gene polymorphisms with adopted. aging and longevity in americans of japanese ancestry . EOS
# REPEATED:
# association analyses of insulin signaling signaling pathway polymorphisms with healthy aging and and in americans of japanese ancestry . EOS
# SINGLE REPEAT:
# association with of insulin signaling with gene polymorphisms with with with with longevity in americans of japanese ancestry . EOS
# MODEL: [[ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]
